# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ls
# Out:
# Pokemon_dataset.ipynb
# combats.csv
# data-sciencetutorial-for-beginners.ipynb
# pokemon.csv
# tests.csv

# %%
data = pd.read_csv('pokemon.csv')

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
f, ax= plt.subplots(figsize = (14, 14))
sns.heatmap(data.corr(), annot=True, fmt='.2f' ,ax=ax)

# %%
data.corr()
# Out:
#                    #        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# #           1.000000  0.097712  0.102664  0.094691  0.089199  0.085596
# HP          0.097712  1.000000  0.422386  0.239622  0.362380  0.378718
# Attack      0.102664  0.422386  1.000000  0.438687  0.396362  0.263990
# Defense     0.094691  0.239622  0.438687  1.000000  0.223549  0.510747
# Sp. Atk     0.089199  0.362380  0.396362  0.223549  1.000000  0.506121
# Sp. Def     0.085596  0.378718  0.263990  0.510747  0.506121  1.000000
# Speed       0.012181  0.175952  0.381240  0.015227  0.473018  0.259133
# Generation  0.983428  0.058683  0.051451  0.042419  0.036437  0.028486
# Legendary   0.154336  0.273620  0.345408  0.246377  0.448907  0.363937
#
#                Speed  Generation  Legendary
# #           0.012181    0.983428   0.154336
# HP          0.175952    0.058683   0.273620
# Attack      0.381240    0.051451   0.345408
# Defense     0.015227    0.042419   0.246377
# ...

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data.plot(kind = 'scatter', x='Attack', y='Defense')

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
best_pokemons = data[(data['Attack']>100) & (data['Defense']>200)]
best_pokemons
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %%
data[np.logical_and(data['Defense']>100, data['Attack']<120)]
# Out:
#        #                  Name  Type 1   Type 2   HP  Attack  Defense  \
# 3      4         Mega Venusaur   Grass   Poison   80     100      123
# 12    13        Mega Blastoise   Water      NaN   79     103      120
# 33    34             Sandslash  Ground      NaN   75     100      110
# 81    82              Graveler    Rock   Ground   55      95      115
# 86    87               Slowbro   Water  Psychic   95      75      110
# ..   ...                   ...     ...      ...  ...     ...      ...
# 787  788  Gourgeist Super Size   Ghost    Grass   85     100      122
# 789  790               Avalugg     Ice      NaN   95     117      184
# 794  795    Zygarde Half Forme  Dragon   Ground  108     100      121
# 795  796               Diancie    Rock    Fairy   50     100      150
# 799  800             Volcanion    Fire    Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 3        122      120     80           1      False
# ...

# %%
def f(*args):
    for i in args:
        print(i)
f(3,5,7)
# Out:
# 3
# 5
# 7

# %%
tot = lambda x,y,z: x*y**z
tot(2,3,4)
# Out:
# 162

# %%
ave_speed = sum(data['Speed'])/len(data['Speed'])
print(ave_speed)
# Out:
# 68.2775

# %%
data['Speed_Level'] = ["high" if i>ave_speed else "low" for i in data['Speed']]

# %%
data.loc[:5, ["Speed_Level","Speed"]]
# Out:
#   Speed_Level  Speed
# 0         low     45
# 1         low     60
# 2        high     80
# 3        high     80
# 4         low     65
# 5        high     80
